# %% [markdown]
# # Epymorph dev log: May 31, 2023
#
# Author: Alexander Nez
#
# as of git hash: 50645d5e6efc58ffc1443a81c308b185288cdbbe
#
# ### SIRH
#
# An advance model of the SIR model as we add a new compartment which is hospitalized. Individuals who are infected can either be hospitalized or remain infected.
#
#
# ### TOML file params
#
# theta = 0.1
#
# beta = 0.5739426782
#
# move_control = 0.9
#
# infection_duration = 4.0
#
# immunity_duration = 90.0
#
# infection_seed_loc = 0
#
# infection_seed_size = 10000
#
# hospitalization_rate = 0.25
#
# hospitalization_duration = 4.0

# %% [markdown]
# # SIRH with no movement
#
# ### plots SIRH model by prevalence
# python -m epymorph run --ipm sirh --mm no --geo pei --params "./scratch/sirh_params.toml" --start_date "2015-01-01" --duration "150d" --chart "p0"
# ### creats SIRH.csv file
# python -m epymorph run --ipm sirh --geo pei --mm no --start_date 2015-01-01 --duration 150d --params ./scratch/sdh_params.toml --out ./scratch/sirh_no.csv
# ### Incidence

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'no',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/sirh_params.toml",
    out_path =None,
    chart = 'e0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (no)
# [✓] Geo (pei)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/sirh_params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# |####################| 100%
# Runtime: 0.045s
# Displaying chart: e0
# Done

# %% [markdown]
# #### Prevalance

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'no',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/params.toml",
    out_path =None,
    chart = 'p0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (no)
# [✓] Geo (pei)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# |####################| 100%
# Runtime: 0.097s
# Displaying chart: p0
# Done

# %% [markdown]
# # SIRH with ice cube movement
#
# ### plots SIRH model by prevalence
# python -m epymorph run --ipm sirh --mm icecube --geo pei --params "./scratch/sirh_params.toml" --start_date "2015-01-01" --duration "150d" --chart "p0"
# ### creats SIRH.csv file
# python -m epymorph run --ipm sirh --geo pei --mm icecube --start_date 2015-01-01 --duration 150d --params ./scratch/sdh_params.toml --out ./scratch/sirh_icecube.csv
# ### incidence

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'icecube',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/params.toml",
    out_path = None,
    chart = 'e0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (icecube)
# [✓] Geo (pei)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# |####################| 100%
# Runtime: 0.363s
# Displaying chart: e0
# Done

# %% [markdown]
# ### Prevalance

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'icecube',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/params.toml",
    out_path =None,
    chart = 'p0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (icecube)
# [✓] Geo (pei)
# [X] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/params.toml)
# ERROR: Unable to load parameters: /Users/alexandernez/Desktop/Github/Epymorph/scratch/params.toml

# %% [markdown]
# ### SIRH with pei movement
#
# ### plots SIRH model by prevalence
# python -m epymorph run --ipm sirh --mm pei --geo pei --params "./scratch/sirh_params.toml" --start_date "2015-01-01" --duration "150d" --chart "p0"
# ### creats SIRH.csv file
# python -m epymorph run --ipm sirh --geo pei --mm pei --start_date 2015-01-01 --duration 150d --params ./scratch/sirh_params.toml --out ./scratch/sirh_pei.csv
#
#
# ### Incidence

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'pei',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/sirh_params.toml",
    out_path = None,
    chart = 'e1',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (pei)
# [✓] Geo (pei)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/sirh_params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# |####################| 100%
# Runtime: 0.253s
# Displaying chart: e1
# Done

# %% [markdown]
# ### Prevalance

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'pei',
    geo_name = 'pei',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/sirh_params.toml",
    out_path = None,
    chart = 'p0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (pei)
# [✓] Geo (pei)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# |####################| 100%
# Runtime: 0.744s
# Displaying chart: p0
# Done

# %% [markdown]
# # SIRH with sparesmod movement
#
# ### plots SIRH model by prevalence
# python -m epymorph run --ipm sirh --mm sparesmod --geo pei --params "./scratch/sirh_params.toml" --start_date "2015-01-01" --duration "150d" --chart "p0"
# # creats SIRH.csv file
# python -m epymorph run --ipm sdh --geo pei --mm sparesmod --start_date 2015-01-01 --duration 150d --params ./scratch/sdh_params.toml --out ./scratch/sirh_pei.csv

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'sparsemod',
    geo_name = 'sparse',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/params.toml",
    out_path = None,
    chart = 'e0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (sparsemod)
# [X] Geo (sparse)
# ERROR: Unknown {type}: {name}

# %% [markdown]
# ### Prevalance

# %%
import os

from epymorph.run import run

dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')

exit_code = run(
    ipm_name = 'sirh',
    mm_name = 'sparsemod',
    geo_name = 'sparsemod',
    start_date_str = '2015-01-01',
    duration_str = '150d',
    params_path = f"{dir}/sirh_params.toml",
    out_path = None,
    chart = 'p0',
    profiling=False
)
# Out:
# Loading requirements:
# [✓] IPM (sirh)
# [✓] MM (sparsemod)
# [✓] Geo (sparsemod)
# [✓] Parameters (file:/Users/alexandernez/Desktop/Github/Epymorph/scratch/sirh_params.toml)
#
# Running simulation:
# • 2015-01-01 to 2015-05-31 (150 days)
# • 6 geo nodes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       3 from epymorph.run import run
#       5 dir = os.path.expanduser('~/Desktop/Github/Epymorph/scratch')
# ----> 7 exit_code = run(
#       8     ipm_name = 'sirh',
#       9     mm_name = 'sparsemod',
#      10     geo_name = 'sparsemod',
#      11     start_date_str = '2015-01-01',
#      12     duration_str = '150d',
#      13     params_path = f"{dir}/sirh_params.toml",
#      14     out_path = None,
#      15     chart = 'p0',
#      16     profiling=False
#      17 )
#
# ...
