# %%
from epymorph.adrios.name_state import nameState

adrio = nameState('f30f434bf5755065f3d8c9b5ef1fd2a0b7bc0727')

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([['Apache County', ' Arizona'],
#        ['Cochise County', ' Arizona'],
#        ['Coconino County', ' Arizona'],
#        ['Gila County', ' Arizona'],
#        ['Graham County', ' Arizona'],
#        ['Greenlee County', ' Arizona'],
#        ['La Paz County', ' Arizona'],
#        ['Maricopa County', ' Arizona'],
#        ['Mohave County', ' Arizona'],
#        ['Navajo County', ' Arizona'],
#        ['Pima County', ' Arizona'],
#        ['Pinal County', ' Arizona'],
#        ['Santa Cruz County', ' Arizona'],
#        ['Yavapai County', ' Arizona'],
#        ['Yuma County', ' Arizona'],
#        ['Adams County', ' Colorado'],
#        ['Alamosa County', ' Colorado'],
#        ['Arapahoe County', ' Colorado'],
#        ['Archuleta County', ' Colorado'],
#        ['Baca County', ' Colorado'],
#        ['Bent County', ' Colorado'],
#        ['Boulder County', ' Colorado'],
#        ['Broomfield County', ' Colorado'],
#        ['Chaffee County', ' Colorado'],
# ...

# %%
from epymorph.adrios.geographic_centroid import GeographicCentroid

adrio = GeographicCentroid()

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([(-109.48882251636141, 35.395526151308545),
#        (-109.75116760476891, 31.879607893023856),
#        (-111.7704971923774, 35.8387443253684),
#        (-110.81171035283734, 33.79974722050316),
#        (-109.8873988146434, 32.932700192649364),
#        (-109.24013441255843, 33.21522083484199),
#        (-113.98132110605167, 33.72924908338436),
#        (-112.49128033166559, 33.34880939358578),
#        (-113.75795404228323, 35.70409895713802),
#        (-110.32140163993228, 35.39965822729559),
#        (-111.78991448524444, 32.09741775958318),
#        (-111.34465410635516, 32.90436613227677),
#        (-110.84659406927926, 31.52602531400177),
#        (-112.55390541813965, 34.59990198132501),
#        (-113.90555762252578, 32.769383716949605),
#        (-104.33776611882, 39.87363181515386),
#        (-105.78832219516865, 37.57292361959731),
#        (-104.33921989594569, 39.64975669469477),
#        (-107.04828569583735, 37.19353613371178),
# ...

# %%
from epymorph.adrios.pop_by_age import PopByAge

adrio = PopByAge('f30f434bf5755065f3d8c9b5ef1fd2a0b7bc0727')

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([[  72124,   23958,   38859,    9307],
#        [ 129647,   32921,   72082,   24644],
#        [ 136701,   39710,   82816,   14175],
#        [  53165,   11921,   27654,   13590],
#        [  37407,   11533,   21373,    4501],
#        [   9023,    2850,    5132,    1041],
#        [  20335,    3959,    9224,    7152],
#        [4018143, 1122756, 2356933,  538454],
#        [ 203362,   42773,  107960,   52629],
#        [ 107656,   33507,   57832,   16317],
#        [ 998537,  252309,  574997,  171231],
#        [ 389772,  106264,  216616,   66892],
#        [  47073,   14706,   25188,    7179],
#        [ 215996,   43020,  114239,   58737],
#        [ 202987,   60120,  108641,   34226],
#        [ 471206,  142554,  285049,   43603],
#        [  16269,    5006,    9262,    2001],
#        [ 608310,  164397,  374514,   69399],
#        [  12174,    2477,    7133,    2564],
#        [   3701,     859,    1909,     933],
#        [   5895,     966,    3999,     930],
# ...

# %%
from epymorph.adrios.median_income import MedianIncome

adrio = MedianIncome('f30f434bf5755065f3d8c9b5ef1fd2a0b7bc0727')

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([ 31757,  45075,  50234,  39751,  45964,  51628,  34466,  54229,
#         38488,  35921,  46162,  49477,  40140,  44748,  40743,  58946,
#         32395,  63265,  46646,  38000,  36791,  70961,  81898,  51092,
#         52554,  67710,  36652,  31321,  31151,  35000,  42452,  53637,
#         31875, 102964,  72214,  84963,  58206,  40423,  56590,  65670,
#         63628,  48071,  57083,  31715,  46014,  70164,  40304,  40603,
#         45367,  60278,  59805,  45067,  39005,  42319,  49322,  48125,
#         51387,  43553,  43999,  48450,  32311,  61624,  56969,  43639,
#         71196,  40179,  41286,  61842,  39672,  64963,  33393,  36324,
#         56047,  44191,  67983,  62372,  45541,  60572,  43105,  47415,
#         51575,  58535,  71799,  39271,  60250,  65212,  78190,  44866,
#         47255,  38923,  41712,  45230,  64832,  52870,  57122,  47668,
#         47725,  42973,  40630,  34565,  32380,  41084,  32500,  38853,
# ...

# %%
from epymorph.adrios.population_density import PopulationDensity

adrio = PopulationDensity('f30f434bf5755065f3d8c9b5ef1fd2a0b7bc0727')

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([1.04549400e+05, 5.28611100e+04, 2.50145900e+04, 2.23502010e+05,
#        2.41506350e+05, 6.89570100e+04, 6.19707700e+04, 6.78680890e+05,
#        7.40858000e+04, 8.44482700e+04, 2.83515000e+04, 6.24464850e+05,
#        8.96723500e+04, 4.15903360e+05, 6.88731180e+05, 1.31741930e+05,
#        4.39624700e+04, 5.40801900e+04, 1.11244100e+04, 1.49293680e+05,
#        3.22832800e+04, 3.93526700e+04, 1.87614830e+05, 5.55486400e+04,
#        1.04434720e+05, 7.90293000e+03, 1.94881500e+04, 2.20509400e+04,
#        1.52379300e+04, 5.12349700e+04, 1.78815100e+04, 1.98373374e+07,
#        1.73638374e+06, 1.49172785e+06, 4.24462353e+06, 4.50621943e+06,
#        5.85639400e+04, 1.34985320e+05, 7.46400010e+05, 1.95036840e+05,
#        1.68862050e+05, 1.08887890e+05, 7.79438800e+04, 4.20575000e+04,
#        2.24870330e+05, 3.82772600e+04, 9.26732911e+06, 1.00643531e+06,
#        4.39190690e+05, 1.28975756e+06, 1.83062117e+06, 7.09575130e+05,
# ...

# %%
from epymorph.adrios.dissimilarity_index import dissimilarityIndex

adrio = dissimilarityIndex('f30f434bf5755065f3d8c9b5ef1fd2a0b7bc0727')

adrio.fetch(nodes=['04','08','49','35','32'])
# Out:
# array([[1.33207317e-03],
#        [1.20349303e-03],
#        [4.43934117e-03],
#        [1.50659693e-02],
#        [9.51657103e-04],
#        [1.86599120e-02],
#        [1.05886653e-03],
#        [6.12395162e-05],
#        [5.94720148e-04],
#        [1.14541211e-04],
#        [1.42228801e-04],
#        [4.53477620e-04],
#        [1.17834828e-03],
#        [1.07769046e-02],
#        [1.90270529e-02],
#        [0.00000000e+00],
#        [1.26649413e-01],
#        [1.22557645e-02],
#        [8.69538086e-02],
#        [3.86331363e-02],
#        [1.01630767e-01],
#        [6.16950886e-03],
#        [1.42576732e-01],
#        [1.48651932e-01],
#        [1.15244020e-01],
#        [1.37827216e-01],
#        [3.99743014e-01],
#        [2.79348132e-01],
#        [2.69498819e-01],
#        [5.25327021e-01],
#        [7.91390668e-03],
#        [4.31236584e-04],
#        [3.52763942e+00],
#        [3.56365804e-02],
#        [6.97637890e-03],
#        [1.30168242e-01],
#        [7.75542573e-03],
# ...
