# %%
'''A jupyter notebook detailing the use of the
particle filter to fit a model with a synthetic data set.'''
# Out:
# 'A jupyter notebook detailing the use of the\nparticle filter to fit a model with a synthetic data set.'

# %%
import numpy as np
from epymorph.forecasting.likelihood import Poisson,Gaussian,NegativeBinomial

from epymorph.forecasting.pipeline import (
    FromRUME,
    ParticleFilterSimulator,
    Observations,
    ModelLink,
)

# %%
from epymorph.kit import *
from epymorph.adrio import acs5, us_tiger

my_rng = np.random.default_rng(1)

rume = SingleStrataRUME.build(
    # Load the Pei IPM
    ipm=ipm.SIRH(),
    # Load the Pei MM
    mm=mm.Centroids(),
    # Describe the geographic scope of our simulation:
    scope=CountyScope.in_counties(["King, WA","Whatcom, WA","Pierce, WA","Snohomish, WA"], year=2015),
    # Create a SingleLocation initializer
    init=init.SingleLocation(location=0, seed_size=100),
    # Set the time-frame to simulate
    time_frame=TimeFrame.of("2015-01-01", 150),
    # Provide model parameter values
    params={
        "beta": 0.3,
        "gamma":0.1,
        "xi":1/90,
        "phi":10,
        "hospitalization_prob":0.05,
        "hospitalization_duration":5,
        # Geographic data can be loaded using ADRIOs
        "centroid": us_tiger.InternalPoint(),
        "population": acs5.Population()
    },
)

# %%
rume.ipm.diagram()

# %%
# Construct a simulator for the RUME
sim = BasicSimulator(rume)

# Run inside a sim_messaging context to display a nice progress bar
with sim_messaging():
    # Run and save the simulation Output object for later
    out = sim.run(
        # Use a seeded RNG (for the sake of keeping this notebook's results consistent)
        # This parameter is optional; by default a new RNG is constructed for each run
        # using numpy's default_rng
        rng_factory=default_rng(1)
    )
# Out:
# Loading gpm:all::mm::population (epymorph.adrio.acs5.Population):
#   |####################| 100%  (0.749s)
# Running simulation (BasicSimulator):
# • 2015-01-01 to 2015-05-30 (150 days)
# • 4 geo nodes
#   |####################| 100%
# Runtime: 0.172s

# %%
# Plot the compartment values in States throughout the simulation.
from epymorph.adrio import csv
from epymorph.tools.data import munge
import seaborn as sns


# cases_df = munge(
#     out,
#     quantity=rume.ipm.select.events("I->H"),
#     time=rume.time_frame.select.all().group("day").agg(),
#     geo=rume.scope.select.all(),
# )

# cases_df.columns = ['date','geoid','value']

# sns.lineplot(data=cases_df,x='date',y='value',hue='geoid')

# cases_df.to_csv('pf_vignettes/synthetic_data_poisson.csv',index=False)

csvadrio = csv.CSVFileAxN(
    file_path='pf_vignettes/synthetic_data_poisson.csv',
    dtype=np.int64,
    key_col=1,
    key_type="geoid",
    time_col=0,
    data_col=2,
    skiprows=1
)

# %%
from epymorph.forecasting.likelihood import NegativeBinomial

num_realizations = 100

pf_scope = CountyScope.in_counties(["King, WA","Whatcom, WA","Pierce, WA","Snohomish, WA"],year=2015)

pf_rume = SingleStrataRUME.build(
    # Load the Pei IPM
    ipm=ipm.SIRH(),
    # Load the Pei MM
    mm=mm.Centroids(),
    # Describe the geographic scope of our simulation:
    scope=pf_scope,
    # Create a SingleLocation initializer
    init=init.RandomLocationsAndRandomSeed(1,1000),
    # Set the time-frame to simulate
    time_frame=TimeFrame.of("2015-01-01", 150),
    # Provide model parameter values
    params={
        "beta": 0.3,
        "gamma":0.1,
        "xi":1/90,
        "phi":10,
        "hospitalization_prob":0.05,
        "hospitalization_duration":5,
        # Geographic data can be loaded using ADRIOs
        "centroid": us_tiger.InternalPoint(),
        "population": acs5.Population()
    },
)

my_observations = Observations(
    source=csvadrio,
    model_link=ModelLink(
        geo=pf_rume.scope.select.all(),
        time=pf_rume.time_frame.select.all().group("day").agg(),
        quantity=pf_rume.ipm.select.events("I->H"),
    ),
    likelihood=NegativeBinomial(r=50),
)

particle_filter_simulator = ParticleFilterSimulator(
        config=FromRUME(pf_rume,num_realizations),
        observations=my_observations,
        save_trajectories=True,
    )

# %%
particle_filter_output = particle_filter_simulator.run(rng=my_rng)
# Out:
# Observation: 0, Label: 2015-01-01, Time Frame: 2015-01-01 (1D),
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Observation: 1, Label: 2015-01-02, Time Frame: 2015-01-02 (1D),
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Observation: 2, Label: 2015-01-03, Time Frame: 2015-01-03 (1D),
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Observation: 3, Label: 2015-01-04, Time Frame: 2015-01-04 (1D),
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
# ...
# Observation: 9, Label: 2015-01-10, Time Frame: 2015-01-10 (1D),
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# Index(['tick', 'date', 'node', 'S', 'I', 'R', 'H', 'S → I', 'I → H', 'I → R',
#        'H → R', 'R → S'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 particle_filter_output = particle_filter_simulator.run(rng=my_rng)
#
# File ~/Desktop/epymorph/Epymorph/epymorph/forecasting/pipeline.py:243, in ParticleFilterSimulator.run(self, rng)
#     242 def run(self, rng):
# --> 243     output = self._run_particle_filter(
#     244         self.rume,
#     245         self.num_realizations,
#     246         self.initial_values,
#     247         self.unknown_params,
#     248         observations=self.observations,
#     249         rng=rng,
#     250         save_trajectories=self.save_trajectories,
#     251     )
#     252     return ParticleFilterOutput(
#     253         simulator=self,
#     254         final_compartment_values=output.final_compartment_values,
#    (...)
#     260         estimated_params = output.estimated_params
#     261     )
#
# File ~/Desktop/epymorph/Epymorph/epymorph/forecasting/pipeline.py:420, in ParticleFilterSimulator._run_particle_filter(self, rume, num_realizations, initial_values, unknown_params, observations, rng, save_trajectories)
#     409 rume_temp, data = self._create_sim_rume(
#     410     rume,
#     411     j_realization,
#    (...)
#     416     rng,
#     417 )
#     419 sim = BasicSimulator(rume_temp)
# --> 420 out_temp = sim.run(rng_factory=lambda: rng)
#     422 print(out_temp.dataframe.columns)
#     424 temp_time_agg = out_temp.rume.time_frame.select.all().agg()
#
# File ~/Desktop/epymorph/Epymorph/epymorph/simulator/basic/basic_simulator.py:126, in BasicSimulator.run(self, params, rng_factory)
#     123     world = ListWorld.from_initials(initial_values)
#     125 with error_gate("compiling the simulation", SimCompilationError):
# --> 126     ipm_exec = IPMExecutor(rume, world, data, rng)
#     127     movement_exec = MovementExecutor(rume, world, data, rng)
#     129 name = self.__class__.__name__
#
# File ~/Desktop/epymorph/Epymorph/epymorph/simulator/basic/ipm_exec.py:189, in IPMExecutor.__init__(self, rume, world, data, rng)
#     186 self._world = world
#     187 self._rng = rng
# --> 189 self._trxs = _compile_transitions(ipm)
#     190 self._apply_matrix = _make_apply_matrix(ipm)
#     191 self._events_leaving_compartment = events_leaving_compartment
#
# File ~/Desktop/epymorph/Epymorph/epymorph/simulator/basic/ipm_exec.py:98, in _compile_transitions(model)
#      95             prob_lambda = lambdify_list(rate_params, prob)
#      96             return CompiledFork(size, rate_lambda, prob_lambda)
# ---> 98 return [f(t) for t in model.transitions]
#
# File ~/Desktop/epymorph/Epymorph/epymorph/simulator/basic/ipm_exec.py:94, in _compile_transitions.<locals>.f(transition)
#      92 case ForkDef(rate, edges, prob):
#      93     size = len(edges)
# ---> 94     rate_lambda = lambdify(rate_params, rate)
#      95     prob_lambda = lambdify_list(rate_params, prob)
#      96     return CompiledFork(size, rate_lambda, prob_lambda)
#
# File ~/Desktop/epymorph/Epymorph/epymorph/sympy_shim.py:41, in lambdify(params, expr)
#      33 """
#      34 Create a lambda function from the given expression,
#      35 taking the given parameters and returning a single result.
#      36 """
#      37 # Note: calling lambdify with `[params]` means we will call it with a list of
#      38 # arguments later (rather than having to spread the list)
#      39 # i.e., f([1,2,3]) rather than f(*[1,2,3])
#      40 # This is better because we have to construct the arguments at run-time as lists.
# ---> 41 return cast(SympyLambda, sy.lambdify([params], expr))
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/utilities/lambdify.py:878, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     876 else:
#     877     cses, _expr = (), expr
# --> 878 funcstr = funcprinter.doprint(funcname, iterable_args, _expr, cses=cses)
#     880 # Collect the module imports from the code printers.
#     881 imp_mod_lines = []
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1141, in _EvaluatorPrinter.doprint(self, funcname, args, expr, cses)
#    1139     cses = zip(subvars, subexprs)
#    1140 else:
# -> 1141     argstrs, expr = self._preprocess(args, expr)
#    1143 # Generate argument unpacking and final argument list
#    1144 funcargs = []
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1205, in _EvaluatorPrinter._preprocess(self, args, expr)
#    1203 for arg, i in reversed(list(ordered(zip(args, range(len(args)))))):
#    1204     if iterable(arg):
# -> 1205         s, expr = self._preprocess(arg, expr)
#    1206     elif isinstance(arg, DeferredVector):
#    1207         s = str(arg)
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/utilities/lambdify.py:1209, in _EvaluatorPrinter._preprocess(self, args, expr)
#    1207     s = str(arg)
#    1208 elif isinstance(arg, Basic) and arg.is_symbol:
# -> 1209     s = self._argrepr(arg)
#    1210     if dummify or not self._is_safe_ident(s):
#    1211         dummy = Dummy()
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/printing/codeprinter.py:152, in CodePrinter.doprint(self, expr, assign_to)
#     148         raise TypeError("{} cannot assign to object of type {}".format(
#     149                 type(self).__name__, type(assign_to)))
#     150     return Assignment(assign_to, expr)
# --> 152 expr = _convert_python_lists(expr)
#     153 expr = _handle_assign_to(expr, assign_to)
#     155 # Remove re(...) nodes due to UnevaluatedExpr.is_real always is None:
#
# File ~/Desktop/epymorph/Epymorph/.venv/lib/python3.12/site-packages/sympy/printing/codeprinter.py:38, in _convert_python_lists(arg)
#      32     """
#      33     Raised if an assignment variable for a loop is missing.
#      34     """
#      35     pass
# ---> 38 def _convert_python_lists(arg):
#      39     if isinstance(arg, list):
#      40         from sympy.codegen.abstract_nodes import List
#
# KeyboardInterrupt:

# %%
from epymorph.simulation import Context

context = Context.of(
    scope=pf_rume.scope,
    # We fetch data starting from the first fitting date to match the first nowcast.
    time_frame=pf_rume.time_frame,
    rng=my_rng,
)
real_data_result = (
    my_observations.source.with_context_internal(context).inspect().result
)
real_data = real_data_result["value"]

real_data_dates = real_data_result["date"][:, 0]

# %%
import matplotlib.pyplot as plt

t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Data fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(particle_filter_output.posterior_values[:,:,node,:],97.5,axis = 1)[:,0]
        lower = np.percentile(particle_filter_output.posterior_values[:,:,node,:],2.5,axis = 1)[:,0]
        data_mean = np.mean((particle_filter_output.posterior_values[:,:,node,:]),axis = 1)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].plot(data_mean,'--',label = 'mean',color = 'black')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_data[:,node],marker = 'x',color = 'red',s= 5)
ax[-1].set_xlabel('Days')
fig.tight_layout()

# %%
'''(100, 300, 4, 4)'''
real_states = out.compartments
real_states = real_states.reshape(150,2,4,4).sum(axis = 1)
pf_states = particle_filter_output.compartments
pf_states = pf_states.reshape(100,150,2,4,4).sum(axis = 2)
print(pf_states.shape)
# Out:
# (100, 150, 4, 4)

# %%
t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Compartment I fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(pf_states[:,:,node,1],97.5,axis = 0)
        lower = np.percentile(pf_states[:,:,node,1],2.5,axis = 0)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_states[:,node,1],marker = 'x',color = 'red',s=5)
ax[-1].set_xlabel('Days')
fig.tight_layout()

# %%
t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Compartment H fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(pf_states[:,:,node,3],97.5,axis = 0)
        lower = np.percentile(pf_states[:,:,node,3],2.5,axis = 0)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_states[:,node,3],marker = 'x',color = 'red',s=5)
ax[-1].set_xlabel('Days')
fig.tight_layout()

# %%
t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Compartment S fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(pf_states[:,:,node,0],97.5,axis = 0)
        lower = np.percentile(pf_states[:,:,node,0],2.5,axis = 0)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_states[:,node,0],marker = 'x',color = 'red',s=5)
ax[-1].set_xlabel('Days')
fig.tight_layout()

# %%
t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Compartment R fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(pf_states[:,:,node,2],97.5,axis = 0)
        lower = np.percentile(pf_states[:,:,node,2],2.5,axis = 0)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_states[:,node,2],marker = 'x',color = 'red',s=5)
ax[-1].set_xlabel('Days')
fig.tight_layout()
