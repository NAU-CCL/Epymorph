# %%
'''Testing if interpolation improves fitting results for real data.'''
# Out:
# 'Testing if interpolation improves fitting results for real data.'

# %%
import numpy as np
import matplotlib.pyplot as plt

from epymorph.kit import *
from epymorph.adrio import acs5
from epymorph.initializer import RandomLocationsAndRandomSeed
from epymorph.simulation import Context

from epymorph.adrio import us_tiger

from epymorph.forecasting.pipeline import (
    FromRUME,
    ParticleFilterSimulator,
    Observations,
    ModelLink,
    UnknownParam
)

from epymorph.forecasting.likelihood import Poisson,NegativeBinomial
from epymorph.forecasting.dynamic_params import BrownianMotion
from epymorph.forecasting.dynamic_params import GaussianPrior
from epymorph.forecasting.param_transformations import ExponentialTransform

from epymorph.adrio.cdc import InfluenzaStateHospitalization
from epymorph.time import EveryNDays

# %%
states = ["AZ", "CO", "NM", "NV"]
rume = SingleStrataRUME.build(
    ipm=ipm.SIRH(),
    mm=mm.No(),
    scope=StateScope.in_states(states, year=2015),
    init=RandomLocationsAndRandomSeed(
        num_locations=len(states),
        seed_max=10_000
    ),
    time_frame=TimeFrame.of("2022-09-15", 7 * 26 + 1),
    params={
        "beta": ExponentialTransform('log_beta'),
        "gamma": 0.2,
        "xi": 1 / 90,
        "hospitalization_prob": 200 / 100_000,
        "hospitalization_duration": 5.0,
        "population": acs5.Population(),
        "phi":5,
        "commuter_proportion":0.30,
        "centroid": us_tiger.InternalPoint(),
    },
)

# %%
from epymorph.simulation import Context
from epymorph.attribute import NamePattern
from math import ceil
from scipy.interpolate import CubicSpline
import pandas as pd

sim_date_range = np.arange(0,rume.time_frame.days,1)
data_date_range = np.arange(0,rume.time_frame.days,7)


context = Context.of(
    scope=rume.scope,
    time_frame=rume.time_frame
)

real_data_result = (
    InfluenzaStateHospitalization().with_context_internal(context).inspect().result
)
real_data = real_data_result["value"]

date_col = np.repeat(rume.time_frame.to_numpy(),rume.scope.nodes)

geo_col = np.resize(rume.scope.node_ids,len(date_col))

data_cum = np.cumsum(real_data,axis = 0)

cum_spline = CubicSpline(data_date_range[1:],data_cum)

cum_spline_data = cum_spline(sim_date_range)

plt.title('Cumulative Data vs Spline')
plt.plot(sim_date_range,cum_spline_data,label = 'spline')
plt.plot(data_date_range[1:],data_cum,label = 'data',marker = 'x')
plt.legend()
plt.show()

interpolated_data = np.round(np.clip(np.gradient(cum_spline_data,axis = 0),0,None)).astype('int')

df = pd.DataFrame(index = None)

df['date'] = date_col
df['geoid'] = geo_col
df['value'] = interpolated_data.flatten()

df.to_csv('./pf_vignettes/interpolated_data.csv',index = False)

# %%
import seaborn as sns

columns = ['date','state','previous_day_admission_influenza_confirmed','total_patients_hospitalized_confirmed_influenza']

df = pd.read_csv('pf_vignettes/COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv')

df = df[df['state'].isin(states)][columns]
df['date'] = pd.to_datetime(df['date'])

df = df.sort_values('date')
df = df.reset_index(drop = True)

date_range = rume.time_frame.to_date_range().to_pandas()
df = df[df['date'].isin(date_range)][columns]

sns.lineplot(data=df,x='date',y='previous_day_admission_influenza_confirmed',hue='state')
# Out:
# <Axes: xlabel='date', ylabel='previous_day_admission_influenza_confirmed'>

# %%
n = len(states)
cols = 2
rows = ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 4*rows), sharex=True)
axes = axes.flatten()

for i in range(n):
    ax = axes[i]
    ax.set_title(f'State {states[i]}')

    ax.plot(sim_date_range,df[df['state'] == states[i]]['previous_day_admission_influenza_confirmed'],color = 'blue',marker = 'x',label = 'real data')
    ax.plot(sim_date_range,interpolated_data[:,i],color = 'red',marker = 'x',label = 'interpolated_data')
    ax.legend()

for j in range(i+1, rows*cols):
    fig.delaxes(axes[j])

fig.tight_layout()

plt.legend()
plt.tight_layout()
plt.show()

# %%
from epymorph.adrio import csv

csvadrio = csv.CSVFileAxN(
    file_path='pf_vignettes/interpolated_data.csv',
    dtype=np.int64,
    key_col=1,
    key_type="geoid",
    time_col=0,
    data_col=2,
    skiprows=1
)

# %%
observations = Observations(
    source=csvadrio,
    model_link=ModelLink(
        quantity=rume.ipm.select.events("I->H"),
        time=rume.time_frame.select.all().group(EveryNDays(1)).agg(),
        geo=rume.scope.select.all(),
    ),
    likelihood=NegativeBinomial(r=10),
)

# %%
num_realizations = 100

unknown_params = {
        "log_beta": UnknownParam(
        prior=GaussianPrior(mean = np.log(0.2),standard_deviation=0.5),
        dynamics=BrownianMotion(
           voliatility = 0.1
        ))
        }

particle_filter_simulator = ParticleFilterSimulator(
        config=FromRUME(rume,num_realizations,unknown_params = unknown_params),
        observations= observations,
        save_trajectories=True,
    )

# %%
rng = np.random.default_rng(0)
particle_filter_output = particle_filter_simulator.run(rng=rng)
# Out:
# Observation: 0, Label: 2022-09-15, Time Frame: 2022-09-15 (1D),
# Observation: 1, Label: 2022-09-16, Time Frame: 2022-09-16 (1D),
# Observation: 2, Label: 2022-09-17, Time Frame: 2022-09-17 (1D),
# Observation: 3, Label: 2022-09-18, Time Frame: 2022-09-18 (1D),
# Observation: 4, Label: 2022-09-19, Time Frame: 2022-09-19 (1D),
# Observation: 5, Label: 2022-09-20, Time Frame: 2022-09-20 (1D),
# Observation: 6, Label: 2022-09-21, Time Frame: 2022-09-21 (1D),
# Observation: 7, Label: 2022-09-22, Time Frame: 2022-09-22 (1D),
# Observation: 8, Label: 2022-09-23, Time Frame: 2022-09-23 (1D),
# Observation: 9, Label: 2022-09-24, Time Frame: 2022-09-24 (1D),
# Observation: 10, Label: 2022-09-25, Time Frame: 2022-09-25 (1D),
# Observation: 11, Label: 2022-09-26, Time Frame: 2022-09-26 (1D),
# Observation: 12, Label: 2022-09-27, Time Frame: 2022-09-27 (1D),
# Observation: 13, Label: 2022-09-28, Time Frame: 2022-09-28 (1D),
# Observation: 14, Label: 2022-09-29, Time Frame: 2022-09-29 (1D),
# Observation: 15, Label: 2022-09-30, Time Frame: 2022-09-30 (1D),
# Observation: 16, Label: 2022-10-01, Time Frame: 2022-10-01 (1D),
# Observation: 17, Label: 2022-10-02, Time Frame: 2022-10-02 (1D),
# Observation: 18, Label: 2022-10-03, Time Frame: 2022-10-03 (1D),
# Observation: 19, Label: 2022-10-04, Time Frame: 2022-10-04 (1D),
# Observation: 20, Label: 2022-10-05, Time Frame: 2022-10-05 (1D),
# Observation: 21, Label: 2022-10-06, Time Frame: 2022-10-06 (1D),
# Observation: 22, Label: 2022-10-07, Time Frame: 2022-10-07 (1D),
# Observation: 23, Label: 2022-10-08, Time Frame: 2022-10-08 (1D),
# Observation: 24, Label: 2022-10-09, Time Frame: 2022-10-09 (1D),
# Observation: 25, Label: 2022-10-10, Time Frame: 2022-10-10 (1D),
# Observation: 26, Label: 2022-10-11, Time Frame: 2022-10-11 (1D),
# Observation: 27, Label: 2022-10-12, Time Frame: 2022-10-12 (1D),
# Observation: 28, Label: 2022-10-13, Time Frame: 2022-10-13 (1D),
# Observation: 29, Label: 2022-10-14, Time Frame: 2022-10-14 (1D),
# Observation: 30, Label: 2022-10-15, Time Frame: 2022-10-15 (1D),
# Observation: 31, Label: 2022-10-16, Time Frame: 2022-10-16 (1D),
# Observation: 32, Label: 2022-10-17, Time Frame: 2022-10-17 (1D),
# Observation: 33, Label: 2022-10-18, Time Frame: 2022-10-18 (1D),
# Observation: 34, Label: 2022-10-19, Time Frame: 2022-10-19 (1D),
# Observation: 35, Label: 2022-10-20, Time Frame: 2022-10-20 (1D),
# Observation: 36, Label: 2022-10-21, Time Frame: 2022-10-21 (1D),
# Observation: 37, Label: 2022-10-22, Time Frame: 2022-10-22 (1D),
# Observation: 38, Label: 2022-10-23, Time Frame: 2022-10-23 (1D),
# Observation: 39, Label: 2022-10-24, Time Frame: 2022-10-24 (1D),
# Observation: 40, Label: 2022-10-25, Time Frame: 2022-10-25 (1D),
# Observation: 41, Label: 2022-10-26, Time Frame: 2022-10-26 (1D),
# Observation: 42, Label: 2022-10-27, Time Frame: 2022-10-27 (1D),
# Observation: 43, Label: 2022-10-28, Time Frame: 2022-10-28 (1D),
# Observation: 44, Label: 2022-10-29, Time Frame: 2022-10-29 (1D),
# Observation: 45, Label: 2022-10-30, Time Frame: 2022-10-30 (1D),
# Observation: 46, Label: 2022-10-31, Time Frame: 2022-10-31 (1D),
# Observation: 47, Label: 2022-11-01, Time Frame: 2022-11-01 (1D),
# Observation: 48, Label: 2022-11-02, Time Frame: 2022-11-02 (1D),
# Observation: 49, Label: 2022-11-03, Time Frame: 2022-11-03 (1D),
# Observation: 50, Label: 2022-11-04, Time Frame: 2022-11-04 (1D),
# Observation: 51, Label: 2022-11-05, Time Frame: 2022-11-05 (1D),
# Observation: 52, Label: 2022-11-06, Time Frame: 2022-11-06 (1D),
# Observation: 53, Label: 2022-11-07, Time Frame: 2022-11-07 (1D),
# Observation: 54, Label: 2022-11-08, Time Frame: 2022-11-08 (1D),
# Observation: 55, Label: 2022-11-09, Time Frame: 2022-11-09 (1D),
# Observation: 56, Label: 2022-11-10, Time Frame: 2022-11-10 (1D),
# Observation: 57, Label: 2022-11-11, Time Frame: 2022-11-11 (1D),
# Observation: 58, Label: 2022-11-12, Time Frame: 2022-11-12 (1D),
# Observation: 59, Label: 2022-11-13, Time Frame: 2022-11-13 (1D),
# Observation: 60, Label: 2022-11-14, Time Frame: 2022-11-14 (1D),
# Observation: 61, Label: 2022-11-15, Time Frame: 2022-11-15 (1D),
# Observation: 62, Label: 2022-11-16, Time Frame: 2022-11-16 (1D),
# Observation: 63, Label: 2022-11-17, Time Frame: 2022-11-17 (1D),
# Observation: 64, Label: 2022-11-18, Time Frame: 2022-11-18 (1D),
# Observation: 65, Label: 2022-11-19, Time Frame: 2022-11-19 (1D),
# Observation: 66, Label: 2022-11-20, Time Frame: 2022-11-20 (1D),
# Observation: 67, Label: 2022-11-21, Time Frame: 2022-11-21 (1D),
# Observation: 68, Label: 2022-11-22, Time Frame: 2022-11-22 (1D),
# Observation: 69, Label: 2022-11-23, Time Frame: 2022-11-23 (1D),
# Observation: 70, Label: 2022-11-24, Time Frame: 2022-11-24 (1D),
# Observation: 71, Label: 2022-11-25, Time Frame: 2022-11-25 (1D),
# Observation: 72, Label: 2022-11-26, Time Frame: 2022-11-26 (1D),
# Observation: 73, Label: 2022-11-27, Time Frame: 2022-11-27 (1D),
# Observation: 74, Label: 2022-11-28, Time Frame: 2022-11-28 (1D),
# Observation: 75, Label: 2022-11-29, Time Frame: 2022-11-29 (1D),
# Observation: 76, Label: 2022-11-30, Time Frame: 2022-11-30 (1D),
# Observation: 77, Label: 2022-12-01, Time Frame: 2022-12-01 (1D),
# Observation: 78, Label: 2022-12-02, Time Frame: 2022-12-02 (1D),
# Observation: 79, Label: 2022-12-03, Time Frame: 2022-12-03 (1D),
# Observation: 80, Label: 2022-12-04, Time Frame: 2022-12-04 (1D),
# Observation: 81, Label: 2022-12-05, Time Frame: 2022-12-05 (1D),
# Observation: 82, Label: 2022-12-06, Time Frame: 2022-12-06 (1D),
# Observation: 83, Label: 2022-12-07, Time Frame: 2022-12-07 (1D),
# Observation: 84, Label: 2022-12-08, Time Frame: 2022-12-08 (1D),
# Observation: 85, Label: 2022-12-09, Time Frame: 2022-12-09 (1D),
# Observation: 86, Label: 2022-12-10, Time Frame: 2022-12-10 (1D),
# Observation: 87, Label: 2022-12-11, Time Frame: 2022-12-11 (1D),
# Observation: 88, Label: 2022-12-12, Time Frame: 2022-12-12 (1D),
# Observation: 89, Label: 2022-12-13, Time Frame: 2022-12-13 (1D),
# Observation: 90, Label: 2022-12-14, Time Frame: 2022-12-14 (1D),
# Observation: 91, Label: 2022-12-15, Time Frame: 2022-12-15 (1D),
# Observation: 92, Label: 2022-12-16, Time Frame: 2022-12-16 (1D),
# Observation: 93, Label: 2022-12-17, Time Frame: 2022-12-17 (1D),
# Observation: 94, Label: 2022-12-18, Time Frame: 2022-12-18 (1D),
# Observation: 95, Label: 2022-12-19, Time Frame: 2022-12-19 (1D),
# Observation: 96, Label: 2022-12-20, Time Frame: 2022-12-20 (1D),
# Observation: 97, Label: 2022-12-21, Time Frame: 2022-12-21 (1D),
# Observation: 98, Label: 2022-12-22, Time Frame: 2022-12-22 (1D),
# Observation: 99, Label: 2022-12-23, Time Frame: 2022-12-23 (1D),
# Observation: 100, Label: 2022-12-24, Time Frame: 2022-12-24 (1D),
# Observation: 101, Label: 2022-12-25, Time Frame: 2022-12-25 (1D),
# Observation: 102, Label: 2022-12-26, Time Frame: 2022-12-26 (1D),
# Observation: 103, Label: 2022-12-27, Time Frame: 2022-12-27 (1D),
# Observation: 104, Label: 2022-12-28, Time Frame: 2022-12-28 (1D),
# Observation: 105, Label: 2022-12-29, Time Frame: 2022-12-29 (1D),
# Observation: 106, Label: 2022-12-30, Time Frame: 2022-12-30 (1D),
# Observation: 107, Label: 2022-12-31, Time Frame: 2022-12-31 (1D),
# Observation: 108, Label: 2023-01-01, Time Frame: 2023-01-01 (1D),
# Observation: 109, Label: 2023-01-02, Time Frame: 2023-01-02 (1D),
# Observation: 110, Label: 2023-01-03, Time Frame: 2023-01-03 (1D),
# Observation: 111, Label: 2023-01-04, Time Frame: 2023-01-04 (1D),
# Observation: 112, Label: 2023-01-05, Time Frame: 2023-01-05 (1D),
# Observation: 113, Label: 2023-01-06, Time Frame: 2023-01-06 (1D),
# Observation: 114, Label: 2023-01-07, Time Frame: 2023-01-07 (1D),
# Observation: 115, Label: 2023-01-08, Time Frame: 2023-01-08 (1D),
# Observation: 116, Label: 2023-01-09, Time Frame: 2023-01-09 (1D),
# Observation: 117, Label: 2023-01-10, Time Frame: 2023-01-10 (1D),
# Observation: 118, Label: 2023-01-11, Time Frame: 2023-01-11 (1D),
# Observation: 119, Label: 2023-01-12, Time Frame: 2023-01-12 (1D),
# Observation: 120, Label: 2023-01-13, Time Frame: 2023-01-13 (1D),
# Observation: 121, Label: 2023-01-14, Time Frame: 2023-01-14 (1D),
# Observation: 122, Label: 2023-01-15, Time Frame: 2023-01-15 (1D),
# Observation: 123, Label: 2023-01-16, Time Frame: 2023-01-16 (1D),
# Observation: 124, Label: 2023-01-17, Time Frame: 2023-01-17 (1D),
# Observation: 125, Label: 2023-01-18, Time Frame: 2023-01-18 (1D),
# Observation: 126, Label: 2023-01-19, Time Frame: 2023-01-19 (1D),
# Observation: 127, Label: 2023-01-20, Time Frame: 2023-01-20 (1D),
# Observation: 128, Label: 2023-01-21, Time Frame: 2023-01-21 (1D),
# Observation: 129, Label: 2023-01-22, Time Frame: 2023-01-22 (1D),
# Observation: 130, Label: 2023-01-23, Time Frame: 2023-01-23 (1D),
# Observation: 131, Label: 2023-01-24, Time Frame: 2023-01-24 (1D),
# Observation: 132, Label: 2023-01-25, Time Frame: 2023-01-25 (1D),
# Observation: 133, Label: 2023-01-26, Time Frame: 2023-01-26 (1D),
# Observation: 134, Label: 2023-01-27, Time Frame: 2023-01-27 (1D),
# Observation: 135, Label: 2023-01-28, Time Frame: 2023-01-28 (1D),
# Observation: 136, Label: 2023-01-29, Time Frame: 2023-01-29 (1D),
# Observation: 137, Label: 2023-01-30, Time Frame: 2023-01-30 (1D),
# Observation: 138, Label: 2023-01-31, Time Frame: 2023-01-31 (1D),
# Observation: 139, Label: 2023-02-01, Time Frame: 2023-02-01 (1D),
# Observation: 140, Label: 2023-02-02, Time Frame: 2023-02-02 (1D),
# Observation: 141, Label: 2023-02-03, Time Frame: 2023-02-03 (1D),
# Observation: 142, Label: 2023-02-04, Time Frame: 2023-02-04 (1D),
# Observation: 143, Label: 2023-02-05, Time Frame: 2023-02-05 (1D),
# Observation: 144, Label: 2023-02-06, Time Frame: 2023-02-06 (1D),
# Observation: 145, Label: 2023-02-07, Time Frame: 2023-02-07 (1D),
# Observation: 146, Label: 2023-02-08, Time Frame: 2023-02-08 (1D),
# Observation: 147, Label: 2023-02-09, Time Frame: 2023-02-09 (1D),
# Observation: 148, Label: 2023-02-10, Time Frame: 2023-02-10 (1D),
# Observation: 149, Label: 2023-02-11, Time Frame: 2023-02-11 (1D),
# Observation: 150, Label: 2023-02-12, Time Frame: 2023-02-12 (1D),
# Observation: 151, Label: 2023-02-13, Time Frame: 2023-02-13 (1D),
# Observation: 152, Label: 2023-02-14, Time Frame: 2023-02-14 (1D),
# Observation: 153, Label: 2023-02-15, Time Frame: 2023-02-15 (1D),
# Observation: 154, Label: 2023-02-16, Time Frame: 2023-02-16 (1D),
# Observation: 155, Label: 2023-02-17, Time Frame: 2023-02-17 (1D),
# Observation: 156, Label: 2023-02-18, Time Frame: 2023-02-18 (1D),
# Observation: 157, Label: 2023-02-19, Time Frame: 2023-02-19 (1D),
# Observation: 158, Label: 2023-02-20, Time Frame: 2023-02-20 (1D),
# Observation: 159, Label: 2023-02-21, Time Frame: 2023-02-21 (1D),
# Observation: 160, Label: 2023-02-22, Time Frame: 2023-02-22 (1D),
# Observation: 161, Label: 2023-02-23, Time Frame: 2023-02-23 (1D),
# Observation: 162, Label: 2023-02-24, Time Frame: 2023-02-24 (1D),
# Observation: 163, Label: 2023-02-25, Time Frame: 2023-02-25 (1D),
# Observation: 164, Label: 2023-02-26, Time Frame: 2023-02-26 (1D),
# Observation: 165, Label: 2023-02-27, Time Frame: 2023-02-27 (1D),
# Observation: 166, Label: 2023-02-28, Time Frame: 2023-02-28 (1D),
# Observation: 167, Label: 2023-03-01, Time Frame: 2023-03-01 (1D),
# Observation: 168, Label: 2023-03-02, Time Frame: 2023-03-02 (1D),
# Observation: 169, Label: 2023-03-03, Time Frame: 2023-03-03 (1D),
# Observation: 170, Label: 2023-03-04, Time Frame: 2023-03-04 (1D),
# Observation: 171, Label: 2023-03-05, Time Frame: 2023-03-05 (1D),
# Observation: 172, Label: 2023-03-06, Time Frame: 2023-03-06 (1D),
# Observation: 173, Label: 2023-03-07, Time Frame: 2023-03-07 (1D),
# Observation: 174, Label: 2023-03-08, Time Frame: 2023-03-08 (1D),
# Observation: 175, Label: 2023-03-09, Time Frame: 2023-03-09 (1D),
# Observation: 176, Label: 2023-03-10, Time Frame: 2023-03-10 (1D),
# Observation: 177, Label: 2023-03-11, Time Frame: 2023-03-11 (1D),
# Observation: 178, Label: 2023-03-12, Time Frame: 2023-03-12 (1D),
# Observation: 179, Label: 2023-03-13, Time Frame: 2023-03-13 (1D),
# Observation: 180, Label: 2023-03-14, Time Frame: 2023-03-14 (1D),
# Observation: 181, Label: 2023-03-15, Time Frame: 2023-03-15 (1D),
# Observation: 182, Label: 2023-03-16, Time Frame: 2023-03-16 (1D),

# %%
from epymorph.simulation import Context
from epymorph.attribute import NamePattern
from math import ceil


data_date_range = np.arange(0,rume.time_frame.days,1)
sim_date_range = np.arange(0,rume.time_frame.days,1)

n = len(states)
cols = 2
rows = ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 4*rows), sharex=True)
axes = axes.flatten()

for i in range(n):
    ax = axes[i]
    ax.set_title(f'State {states[i]}')

    lower = np.percentile(particle_filter_output.posterior_values[:, :, i, :], 2.5, axis=1).squeeze()
    upper = np.percentile(particle_filter_output.posterior_values[:, :, i, :], 97.5, axis=1).squeeze()
    mean  = np.mean(particle_filter_output.posterior_values[:, :, i, :], axis=1).squeeze()

    ax.fill_between(data_date_range, lower, upper, alpha=0.3, label='95% CI')
    ax.plot(data_date_range, mean, color='black', label='Mean of PF')
    ax.scatter(sim_date_range,df[df['state'] == states[i]]['previous_day_admission_influenza_confirmed'],color = 'blue',marker = 'x',label = 'real data')
    ax.scatter(data_date_range,interpolated_data[:,i],marker = 'x',color = 'red',label = 'Interpolated data')
    ax.legend()

for j in range(i+1, rows*cols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

fig.tight_layout()

# %%
cols = 2
rows = ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 4*rows), sharex=True)
axes = axes.flatten()


for i in range(n):
    ax = axes[i]
    ax.set_title(f'State {states[i]}')

    lower = np.percentile(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:, :, i], 2.5, axis=0).squeeze()
    upper = np.percentile(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:, :, i], 97.5, axis=0).squeeze()
    mean  = np.mean(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:, :, i], axis=0).squeeze()

    ax.fill_between(sim_date_range, np.exp(lower), np.exp(upper), alpha=0.3, label='95% CI')
    ax.plot(sim_date_range, np.exp(mean), color='black', label='Mean of PF')
    ax.legend()

for j in range(i+1, rows*cols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
a = particle_filter_output.compartments.shape[3]   # = 4
compartment_labels = ['S','I','R','H']

rows = n                       # one row per state
cols = a                       # one column per last-axis element

fig, axes = plt.subplots(rows, cols,
                         figsize=(6*cols, 3.5*rows),
                         sharex=True)

# ensure axes is 2-D even if n or a = 1
axes = np.atleast_2d(axes)

for i in range(n):               # loop states
    for k in range(a):           # loop final-axis components
        ax = axes[i, k]

        data = particle_filter_output.compartments[:, :, i, k]

        lower = np.percentile(data, 2.5, axis=0).squeeze()
        upper = np.percentile(data, 97.5, axis=0).squeeze()
        mean  = np.mean(data, axis=0).squeeze()

        ax.fill_between(sim_date_range, lower, upper, alpha=0.3)
        ax.plot(sim_date_range, mean, color='black')

        if(compartment_labels[k] == 'H'):
            ax.scatter(sim_date_range,df[df['state'] == states[i]]['total_patients_hospitalized_confirmed_influenza'],color = 'blue',marker = 'x',label = 'real data')

        # Titles by row / col for readability
        if i == 0:
            ax.set_title(f'Compartment {compartment_labels[k]}')
        if k == 0:
            ax.set_ylabel(f'State {states[i]}')

plt.tight_layout()
plt.show()
