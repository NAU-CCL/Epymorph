# %%
'''Extracts the daily hospital admissions data from COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv'''
# Out:
# 'Extracts the daily hospital admissions data from COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv'

# %%
import pandas as pd
import numpy as np
import seaborn as sns

columns = ['date','state','previous_day_admission_influenza_confirmed','total_patients_hospitalized_confirmed_influenza']
states = ["AZ", "CO", "NM", "UT"]

df = pd.read_csv('pf_vignettes/COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv')

df = df[df['state'].isin(states)][columns]
df['date'] = pd.to_datetime(df['date'])

df = df.sort_values('date')

sns.lineplot(data=df,x='date',y='previous_day_admission_influenza_confirmed',hue='state')
# Out:
# Index(['state', 'date', 'critical_staffing_shortage_today_yes',
#        'critical_staffing_shortage_today_no',
#        'critical_staffing_shortage_today_not_reported',
#        'critical_staffing_shortage_anticipated_within_week_yes',
#        'critical_staffing_shortage_anticipated_within_week_no',
#        'critical_staffing_shortage_anticipated_within_week_not_reported',
#        'hospital_onset_covid', 'hospital_onset_covid_coverage',
#        ...
#        'previous_day_admission_pediatric_covid_confirmed_5_11',
#        'previous_day_admission_pediatric_covid_confirmed_5_11_coverage',
#        'previous_day_admission_pediatric_covid_confirmed_unknown',
#        'previous_day_admission_pediatric_covid_confirmed_unknown_coverage',
#        'staffed_icu_pediatric_patients_confirmed_covid',
#        'staffed_icu_pediatric_patients_confirmed_covid_coverage',
#        'staffed_pediatric_icu_bed_occupancy',
#        'staffed_pediatric_icu_bed_occupancy_coverage',
# ...

# %%
sns.lineplot(data=df,x='date',y='total_patients_hospitalized_confirmed_influenza',hue='state')
# Out:
# <Axes: xlabel='date', ylabel='total_patients_hospitalized_confirmed_influenza'>
