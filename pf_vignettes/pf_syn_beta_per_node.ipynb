# %%
'''A jupyter notebook detailing the use of the
particle filter to fit a model with a time dependent beta and synthetic data set. 
This one is different betas for every node. 
'''
# Out:
# 'A jupyter notebook detailing the use of the\nparticle filter to fit a model with a time dependent beta and synthetic data set. \nThis one is different betas for every node. \n'

# %%
import numpy as np
import matplotlib.pyplot as plt
from epymorph.forecasting.likelihood import Poisson,Gaussian,NegativeBinomial
from epymorph.attribute import NamePattern
from epymorph.kit import *

from epymorph.forecasting.pipeline import (
    FromRUME,
    ParticleFilterSimulator,
    Observations,
    ModelLink,
    UnknownParam
)

from epymorph.simulation import Context
from epymorph.adrio import acs5, us_tiger
from epymorph.forecasting.param_transformations import ExponentialTransform
from epymorph.forecasting.dynamic_params import GaussianPrior, OrnsteinUhlenbeck

# %%
sim_time_frame = TimeFrame.of("2015-01-01", 365)

my_rng = np.random.default_rng(1)
'''Generate a random time dependent beta'''
log_beta_damping = np.array([1 / 35,1/35,1/35,1/35])
log_beta_mean = np.array([np.log(0.15),np.log(0.4),np.log(0.25),np.log(0.5)])
log_beta_standard_deviation = np.array([0.25,0.25,0.25,0.25])
initial_log_beta = np.array([np.log(0.15),np.log(0.2),np.log(0.4),np.log(0.5)])

delta_t = 1. 

A = np.exp(-log_beta_damping * delta_t)
M = log_beta_mean * (np.exp(-log_beta_damping * delta_t) - 1)
C = log_beta_standard_deviation * np.sqrt(1-np.exp(-2*log_beta_damping * delta_t))



log_beta = np.zeros((4,sim_time_frame.duration_days,))
log_beta[:,0] = initial_log_beta

for day in range(1,sim_time_frame.duration_days): 
    log_beta[:,day] = A * log_beta[:,day-1] - M + C * my_rng.normal(size = (4,))

beta = np.exp(log_beta)

# %%
plt.title('$\\beta$ over Time by Node')
plt.xlabel('Days')
for node in range(4): 
    plt.plot(beta[node,:],label = f"Node: {node}")
plt.legend()
plt.show()

# %%
rume = SingleStrataRUME.build(
    # Load the Pei IPM
    ipm=ipm.SIRH(),
    # Load the Pei MM
    mm=mm.Centroids(),
    # Describe the geographic scope of our simulation:
    scope=CountyScope.in_counties(["King, WA","Whatcom, WA","Pierce, WA","Snohomish, WA"], year=2015),
    # Create a SingleLocation initializer
    init=init.SingleLocation(location=0, seed_size=1000),
    # Set the time-frame to simulate
    time_frame=sim_time_frame,
    # Provide model parameter values
    params={
        "beta": beta.T,
        "gamma":0.1,
        "xi":1/90,
        "phi":10,
        "hospitalization_prob":0.05,
        "hospitalization_duration":5,
        # Geographic data can be loaded using ADRIOs
        "centroid": us_tiger.InternalPoint(),
        "population": acs5.Population()
    },
)

# %%
rume.ipm.diagram()

# %%
# Construct a simulator for the RUME
sim = BasicSimulator(rume)

# Run inside a sim_messaging context to display a nice progress bar
with sim_messaging():
    # Run and save the simulation Output object for later
    out = sim.run(
        # Use a seeded RNG (for the sake of keeping this notebook's results consistent)
        # This parameter is optional; by default a new RNG is constructed for each run
        # using numpy's default_rng
        rng_factory=default_rng(1)
    )
# Out:
# Loading gpm:all::mm::population (epymorph.adrio.acs5.Population):
#   |####################| 100%  (0.651s)
# Running simulation (BasicSimulator):
# • 2015-01-01 to 2015-12-31 (365 days)
# • 4 geo nodes
#   |####################| 100%
# Runtime: 0.428s

# %%
# Plot the compartment values in States throughout the simulation.
from epymorph.adrio import csv
from epymorph.tools.data import munge
import seaborn as sns


cases_df = munge(
    out,
    quantity=rume.ipm.select.events("I->H"),
    time=rume.time_frame.select.all().group("day").agg(),
    geo=rume.scope.select.all(),
)

cases_df.columns = ['date','geoid','value']

'''Negative binomial scale parameter, as r->inf NB->Poisson. '''
r = 100
cases_df['value'] = my_rng.negative_binomial(p = r/(r + cases_df['value']),n=r)

sns.lineplot(data=cases_df,x='date',y='value',hue='geoid')

cases_df.to_csv('pf_vignettes/synthetic_data.csv',index=False)

csvadrio = csv.CSVFileAxN(
    file_path='pf_vignettes/synthetic_data.csv',
    dtype=np.int64,
    key_col=1,
    key_type="geoid",
    time_col=0,
    data_col=2,
    skiprows=1
)

# %%
num_realizations = 100

pf_scope = CountyScope.in_counties(["King, WA","Whatcom, WA","Pierce, WA","Snohomish, WA"],year=2015)

pf_rume = SingleStrataRUME.build(
    # Load the Pei IPM
    ipm=ipm.SIRH(),
    # Load the Pei MM
    mm=mm.Centroids(),
    # Describe the geographic scope of our simulation:
    scope=pf_scope,
    # Create a SingleLocation initializer
    init=init.RandomLocationsAndRandomSeed(1,10000),
    # Set the time-frame to simulate
    time_frame=sim_time_frame,
    # Provide model parameter values
    params={
        "beta": ExponentialTransform("log_beta"),
        "gamma":0.1,
        "xi":1/90,
        "phi":10,
        "hospitalization_prob":0.05,
        "hospitalization_duration":5,
        # Geographic data can be loaded using ADRIOs
        "centroid": us_tiger.InternalPoint(),
        "population": acs5.Population()
    },
)

my_observations = Observations(
    source=csvadrio,
    model_link=ModelLink(
        geo=pf_rume.scope.select.all(),
        time=pf_rume.time_frame.select.all().group("day").agg(),
        quantity=pf_rume.ipm.select.events("I->H"),
    ),
    likelihood=NegativeBinomial(r=r),
)

my_unknown_params = {
    "log_beta": UnknownParam(
        prior=GaussianPrior(
            mean=log_beta_mean,
            standard_deviation=log_beta_standard_deviation,
        ),
        dynamics=OrnsteinUhlenbeck(
            damping=log_beta_damping,
            mean=log_beta_mean,
            standard_deviation=log_beta_standard_deviation,
        ),
    )
}


particle_filter_simulator = ParticleFilterSimulator(
        config=FromRUME(pf_rume,num_realizations,unknown_params = my_unknown_params),
        observations=my_observations,
        save_trajectories=True,
    )

# %%
particle_filter_output = particle_filter_simulator.run(rng=my_rng)
# Out:
# Observation: 0, Label: 2015-01-01, Time Frame: 2015-01-01 (1D),
# Observation: 1, Label: 2015-01-02, Time Frame: 2015-01-02 (1D),
# Observation: 2, Label: 2015-01-03, Time Frame: 2015-01-03 (1D),
# Observation: 3, Label: 2015-01-04, Time Frame: 2015-01-04 (1D),
# Observation: 4, Label: 2015-01-05, Time Frame: 2015-01-05 (1D),
# Observation: 5, Label: 2015-01-06, Time Frame: 2015-01-06 (1D),
# Observation: 6, Label: 2015-01-07, Time Frame: 2015-01-07 (1D),
# Observation: 7, Label: 2015-01-08, Time Frame: 2015-01-08 (1D),
# Observation: 8, Label: 2015-01-09, Time Frame: 2015-01-09 (1D),
# Observation: 9, Label: 2015-01-10, Time Frame: 2015-01-10 (1D),
# Observation: 10, Label: 2015-01-11, Time Frame: 2015-01-11 (1D),
# Observation: 11, Label: 2015-01-12, Time Frame: 2015-01-12 (1D),
# Observation: 12, Label: 2015-01-13, Time Frame: 2015-01-13 (1D),
# Observation: 13, Label: 2015-01-14, Time Frame: 2015-01-14 (1D),
# Observation: 14, Label: 2015-01-15, Time Frame: 2015-01-15 (1D),
# Observation: 15, Label: 2015-01-16, Time Frame: 2015-01-16 (1D),
# Observation: 16, Label: 2015-01-17, Time Frame: 2015-01-17 (1D),
# Observation: 17, Label: 2015-01-18, Time Frame: 2015-01-18 (1D),
# Observation: 18, Label: 2015-01-19, Time Frame: 2015-01-19 (1D),
# Observation: 19, Label: 2015-01-20, Time Frame: 2015-01-20 (1D),
# Observation: 20, Label: 2015-01-21, Time Frame: 2015-01-21 (1D),
# Observation: 21, Label: 2015-01-22, Time Frame: 2015-01-22 (1D),
# Observation: 22, Label: 2015-01-23, Time Frame: 2015-01-23 (1D),
# Observation: 23, Label: 2015-01-24, Time Frame: 2015-01-24 (1D),
# Observation: 24, Label: 2015-01-25, Time Frame: 2015-01-25 (1D),
# Observation: 25, Label: 2015-01-26, Time Frame: 2015-01-26 (1D),
# Observation: 26, Label: 2015-01-27, Time Frame: 2015-01-27 (1D),
# Observation: 27, Label: 2015-01-28, Time Frame: 2015-01-28 (1D),
# Observation: 28, Label: 2015-01-29, Time Frame: 2015-01-29 (1D),
# Observation: 29, Label: 2015-01-30, Time Frame: 2015-01-30 (1D),
# Observation: 30, Label: 2015-01-31, Time Frame: 2015-01-31 (1D),
# Observation: 31, Label: 2015-02-01, Time Frame: 2015-02-01 (1D),
# Observation: 32, Label: 2015-02-02, Time Frame: 2015-02-02 (1D),
# Observation: 33, Label: 2015-02-03, Time Frame: 2015-02-03 (1D),
# Observation: 34, Label: 2015-02-04, Time Frame: 2015-02-04 (1D),
# Observation: 35, Label: 2015-02-05, Time Frame: 2015-02-05 (1D),
# Observation: 36, Label: 2015-02-06, Time Frame: 2015-02-06 (1D),
# Observation: 37, Label: 2015-02-07, Time Frame: 2015-02-07 (1D),
# Observation: 38, Label: 2015-02-08, Time Frame: 2015-02-08 (1D),
# Observation: 39, Label: 2015-02-09, Time Frame: 2015-02-09 (1D),
# Observation: 40, Label: 2015-02-10, Time Frame: 2015-02-10 (1D),
# Observation: 41, Label: 2015-02-11, Time Frame: 2015-02-11 (1D),
# Observation: 42, Label: 2015-02-12, Time Frame: 2015-02-12 (1D),
# Observation: 43, Label: 2015-02-13, Time Frame: 2015-02-13 (1D),
# Observation: 44, Label: 2015-02-14, Time Frame: 2015-02-14 (1D),
# Observation: 45, Label: 2015-02-15, Time Frame: 2015-02-15 (1D),
# Observation: 46, Label: 2015-02-16, Time Frame: 2015-02-16 (1D),
# Observation: 47, Label: 2015-02-17, Time Frame: 2015-02-17 (1D),
# Observation: 48, Label: 2015-02-18, Time Frame: 2015-02-18 (1D),
# Observation: 49, Label: 2015-02-19, Time Frame: 2015-02-19 (1D),
# Observation: 50, Label: 2015-02-20, Time Frame: 2015-02-20 (1D),
# Observation: 51, Label: 2015-02-21, Time Frame: 2015-02-21 (1D),
# Observation: 52, Label: 2015-02-22, Time Frame: 2015-02-22 (1D),
# Observation: 53, Label: 2015-02-23, Time Frame: 2015-02-23 (1D),
# Observation: 54, Label: 2015-02-24, Time Frame: 2015-02-24 (1D),
# Observation: 55, Label: 2015-02-25, Time Frame: 2015-02-25 (1D),
# Observation: 56, Label: 2015-02-26, Time Frame: 2015-02-26 (1D),
# Observation: 57, Label: 2015-02-27, Time Frame: 2015-02-27 (1D),
# Observation: 58, Label: 2015-02-28, Time Frame: 2015-02-28 (1D),
# Observation: 59, Label: 2015-03-01, Time Frame: 2015-03-01 (1D),
# Observation: 60, Label: 2015-03-02, Time Frame: 2015-03-02 (1D),
# Observation: 61, Label: 2015-03-03, Time Frame: 2015-03-03 (1D),
# Observation: 62, Label: 2015-03-04, Time Frame: 2015-03-04 (1D),
# Observation: 63, Label: 2015-03-05, Time Frame: 2015-03-05 (1D),
# Observation: 64, Label: 2015-03-06, Time Frame: 2015-03-06 (1D),
# Observation: 65, Label: 2015-03-07, Time Frame: 2015-03-07 (1D),
# Observation: 66, Label: 2015-03-08, Time Frame: 2015-03-08 (1D),
# Observation: 67, Label: 2015-03-09, Time Frame: 2015-03-09 (1D),
# Observation: 68, Label: 2015-03-10, Time Frame: 2015-03-10 (1D),
# Observation: 69, Label: 2015-03-11, Time Frame: 2015-03-11 (1D),
# Observation: 70, Label: 2015-03-12, Time Frame: 2015-03-12 (1D),
# Observation: 71, Label: 2015-03-13, Time Frame: 2015-03-13 (1D),
# Observation: 72, Label: 2015-03-14, Time Frame: 2015-03-14 (1D),
# Observation: 73, Label: 2015-03-15, Time Frame: 2015-03-15 (1D),
# Observation: 74, Label: 2015-03-16, Time Frame: 2015-03-16 (1D),
# Observation: 75, Label: 2015-03-17, Time Frame: 2015-03-17 (1D),
# Observation: 76, Label: 2015-03-18, Time Frame: 2015-03-18 (1D),
# Observation: 77, Label: 2015-03-19, Time Frame: 2015-03-19 (1D),
# Observation: 78, Label: 2015-03-20, Time Frame: 2015-03-20 (1D),
# Observation: 79, Label: 2015-03-21, Time Frame: 2015-03-21 (1D),
# Observation: 80, Label: 2015-03-22, Time Frame: 2015-03-22 (1D),
# Observation: 81, Label: 2015-03-23, Time Frame: 2015-03-23 (1D),
# Observation: 82, Label: 2015-03-24, Time Frame: 2015-03-24 (1D),
# Observation: 83, Label: 2015-03-25, Time Frame: 2015-03-25 (1D),
# Observation: 84, Label: 2015-03-26, Time Frame: 2015-03-26 (1D),
# Observation: 85, Label: 2015-03-27, Time Frame: 2015-03-27 (1D),
# Observation: 86, Label: 2015-03-28, Time Frame: 2015-03-28 (1D),
# Observation: 87, Label: 2015-03-29, Time Frame: 2015-03-29 (1D),
# Observation: 88, Label: 2015-03-30, Time Frame: 2015-03-30 (1D),
# Observation: 89, Label: 2015-03-31, Time Frame: 2015-03-31 (1D),
# Observation: 90, Label: 2015-04-01, Time Frame: 2015-04-01 (1D),
# Observation: 91, Label: 2015-04-02, Time Frame: 2015-04-02 (1D),
# Observation: 92, Label: 2015-04-03, Time Frame: 2015-04-03 (1D),
# Observation: 93, Label: 2015-04-04, Time Frame: 2015-04-04 (1D),
# Observation: 94, Label: 2015-04-05, Time Frame: 2015-04-05 (1D),
# Observation: 95, Label: 2015-04-06, Time Frame: 2015-04-06 (1D),
# Observation: 96, Label: 2015-04-07, Time Frame: 2015-04-07 (1D),
# Observation: 97, Label: 2015-04-08, Time Frame: 2015-04-08 (1D),
# Observation: 98, Label: 2015-04-09, Time Frame: 2015-04-09 (1D),
# Observation: 99, Label: 2015-04-10, Time Frame: 2015-04-10 (1D),
# Observation: 100, Label: 2015-04-11, Time Frame: 2015-04-11 (1D),
# Observation: 101, Label: 2015-04-12, Time Frame: 2015-04-12 (1D),
# Observation: 102, Label: 2015-04-13, Time Frame: 2015-04-13 (1D),
# Observation: 103, Label: 2015-04-14, Time Frame: 2015-04-14 (1D),
# Observation: 104, Label: 2015-04-15, Time Frame: 2015-04-15 (1D),
# Observation: 105, Label: 2015-04-16, Time Frame: 2015-04-16 (1D),
# Observation: 106, Label: 2015-04-17, Time Frame: 2015-04-17 (1D),
# Observation: 107, Label: 2015-04-18, Time Frame: 2015-04-18 (1D),
# Observation: 108, Label: 2015-04-19, Time Frame: 2015-04-19 (1D),
# Observation: 109, Label: 2015-04-20, Time Frame: 2015-04-20 (1D),
# Observation: 110, Label: 2015-04-21, Time Frame: 2015-04-21 (1D),
# Observation: 111, Label: 2015-04-22, Time Frame: 2015-04-22 (1D),
# Observation: 112, Label: 2015-04-23, Time Frame: 2015-04-23 (1D),
# Observation: 113, Label: 2015-04-24, Time Frame: 2015-04-24 (1D),
# Observation: 114, Label: 2015-04-25, Time Frame: 2015-04-25 (1D),
# Observation: 115, Label: 2015-04-26, Time Frame: 2015-04-26 (1D),
# Observation: 116, Label: 2015-04-27, Time Frame: 2015-04-27 (1D),
# Observation: 117, Label: 2015-04-28, Time Frame: 2015-04-28 (1D),
# Observation: 118, Label: 2015-04-29, Time Frame: 2015-04-29 (1D),
# Observation: 119, Label: 2015-04-30, Time Frame: 2015-04-30 (1D),
# Observation: 120, Label: 2015-05-01, Time Frame: 2015-05-01 (1D),
# Observation: 121, Label: 2015-05-02, Time Frame: 2015-05-02 (1D),
# Observation: 122, Label: 2015-05-03, Time Frame: 2015-05-03 (1D),
# Observation: 123, Label: 2015-05-04, Time Frame: 2015-05-04 (1D),
# Observation: 124, Label: 2015-05-05, Time Frame: 2015-05-05 (1D),
# Observation: 125, Label: 2015-05-06, Time Frame: 2015-05-06 (1D),
# Observation: 126, Label: 2015-05-07, Time Frame: 2015-05-07 (1D),
# Observation: 127, Label: 2015-05-08, Time Frame: 2015-05-08 (1D),
# Observation: 128, Label: 2015-05-09, Time Frame: 2015-05-09 (1D),
# Observation: 129, Label: 2015-05-10, Time Frame: 2015-05-10 (1D),
# Observation: 130, Label: 2015-05-11, Time Frame: 2015-05-11 (1D),
# Observation: 131, Label: 2015-05-12, Time Frame: 2015-05-12 (1D),
# Observation: 132, Label: 2015-05-13, Time Frame: 2015-05-13 (1D),
# Observation: 133, Label: 2015-05-14, Time Frame: 2015-05-14 (1D),
# Observation: 134, Label: 2015-05-15, Time Frame: 2015-05-15 (1D),
# Observation: 135, Label: 2015-05-16, Time Frame: 2015-05-16 (1D),
# Observation: 136, Label: 2015-05-17, Time Frame: 2015-05-17 (1D),
# Observation: 137, Label: 2015-05-18, Time Frame: 2015-05-18 (1D),
# Observation: 138, Label: 2015-05-19, Time Frame: 2015-05-19 (1D),
# Observation: 139, Label: 2015-05-20, Time Frame: 2015-05-20 (1D),
# Observation: 140, Label: 2015-05-21, Time Frame: 2015-05-21 (1D),
# Observation: 141, Label: 2015-05-22, Time Frame: 2015-05-22 (1D),
# Observation: 142, Label: 2015-05-23, Time Frame: 2015-05-23 (1D),
# Observation: 143, Label: 2015-05-24, Time Frame: 2015-05-24 (1D),
# Observation: 144, Label: 2015-05-25, Time Frame: 2015-05-25 (1D),
# Observation: 145, Label: 2015-05-26, Time Frame: 2015-05-26 (1D),
# Observation: 146, Label: 2015-05-27, Time Frame: 2015-05-27 (1D),
# Observation: 147, Label: 2015-05-28, Time Frame: 2015-05-28 (1D),
# Observation: 148, Label: 2015-05-29, Time Frame: 2015-05-29 (1D),
# Observation: 149, Label: 2015-05-30, Time Frame: 2015-05-30 (1D),
# Observation: 150, Label: 2015-05-31, Time Frame: 2015-05-31 (1D),
# Observation: 151, Label: 2015-06-01, Time Frame: 2015-06-01 (1D),
# Observation: 152, Label: 2015-06-02, Time Frame: 2015-06-02 (1D),
# Observation: 153, Label: 2015-06-03, Time Frame: 2015-06-03 (1D),
# Observation: 154, Label: 2015-06-04, Time Frame: 2015-06-04 (1D),
# Observation: 155, Label: 2015-06-05, Time Frame: 2015-06-05 (1D),
# Observation: 156, Label: 2015-06-06, Time Frame: 2015-06-06 (1D),
# Observation: 157, Label: 2015-06-07, Time Frame: 2015-06-07 (1D),
# Observation: 158, Label: 2015-06-08, Time Frame: 2015-06-08 (1D),
# Observation: 159, Label: 2015-06-09, Time Frame: 2015-06-09 (1D),
# Observation: 160, Label: 2015-06-10, Time Frame: 2015-06-10 (1D),
# Observation: 161, Label: 2015-06-11, Time Frame: 2015-06-11 (1D),
# Observation: 162, Label: 2015-06-12, Time Frame: 2015-06-12 (1D),
# Observation: 163, Label: 2015-06-13, Time Frame: 2015-06-13 (1D),
# Observation: 164, Label: 2015-06-14, Time Frame: 2015-06-14 (1D),
# Observation: 165, Label: 2015-06-15, Time Frame: 2015-06-15 (1D),
# Observation: 166, Label: 2015-06-16, Time Frame: 2015-06-16 (1D),
# Observation: 167, Label: 2015-06-17, Time Frame: 2015-06-17 (1D),
# Observation: 168, Label: 2015-06-18, Time Frame: 2015-06-18 (1D),
# Observation: 169, Label: 2015-06-19, Time Frame: 2015-06-19 (1D),
# Observation: 170, Label: 2015-06-20, Time Frame: 2015-06-20 (1D),
# Observation: 171, Label: 2015-06-21, Time Frame: 2015-06-21 (1D),
# Observation: 172, Label: 2015-06-22, Time Frame: 2015-06-22 (1D),
# Observation: 173, Label: 2015-06-23, Time Frame: 2015-06-23 (1D),
# Observation: 174, Label: 2015-06-24, Time Frame: 2015-06-24 (1D),
# Observation: 175, Label: 2015-06-25, Time Frame: 2015-06-25 (1D),
# Observation: 176, Label: 2015-06-26, Time Frame: 2015-06-26 (1D),
# Observation: 177, Label: 2015-06-27, Time Frame: 2015-06-27 (1D),
# Observation: 178, Label: 2015-06-28, Time Frame: 2015-06-28 (1D),
# Observation: 179, Label: 2015-06-29, Time Frame: 2015-06-29 (1D),
# Observation: 180, Label: 2015-06-30, Time Frame: 2015-06-30 (1D),
# Observation: 181, Label: 2015-07-01, Time Frame: 2015-07-01 (1D),
# Observation: 182, Label: 2015-07-02, Time Frame: 2015-07-02 (1D),
# Observation: 183, Label: 2015-07-03, Time Frame: 2015-07-03 (1D),
# Observation: 184, Label: 2015-07-04, Time Frame: 2015-07-04 (1D),
# Observation: 185, Label: 2015-07-05, Time Frame: 2015-07-05 (1D),
# Observation: 186, Label: 2015-07-06, Time Frame: 2015-07-06 (1D),
# Observation: 187, Label: 2015-07-07, Time Frame: 2015-07-07 (1D),
# Observation: 188, Label: 2015-07-08, Time Frame: 2015-07-08 (1D),
# Observation: 189, Label: 2015-07-09, Time Frame: 2015-07-09 (1D),
# Observation: 190, Label: 2015-07-10, Time Frame: 2015-07-10 (1D),
# Observation: 191, Label: 2015-07-11, Time Frame: 2015-07-11 (1D),
# Observation: 192, Label: 2015-07-12, Time Frame: 2015-07-12 (1D),
# Observation: 193, Label: 2015-07-13, Time Frame: 2015-07-13 (1D),
# Observation: 194, Label: 2015-07-14, Time Frame: 2015-07-14 (1D),
# Observation: 195, Label: 2015-07-15, Time Frame: 2015-07-15 (1D),
# Observation: 196, Label: 2015-07-16, Time Frame: 2015-07-16 (1D),
# Observation: 197, Label: 2015-07-17, Time Frame: 2015-07-17 (1D),
# Observation: 198, Label: 2015-07-18, Time Frame: 2015-07-18 (1D),
# Observation: 199, Label: 2015-07-19, Time Frame: 2015-07-19 (1D),
# Observation: 200, Label: 2015-07-20, Time Frame: 2015-07-20 (1D),
# Observation: 201, Label: 2015-07-21, Time Frame: 2015-07-21 (1D),
# Observation: 202, Label: 2015-07-22, Time Frame: 2015-07-22 (1D),
# Observation: 203, Label: 2015-07-23, Time Frame: 2015-07-23 (1D),
# Observation: 204, Label: 2015-07-24, Time Frame: 2015-07-24 (1D),
# Observation: 205, Label: 2015-07-25, Time Frame: 2015-07-25 (1D),
# Observation: 206, Label: 2015-07-26, Time Frame: 2015-07-26 (1D),
# Observation: 207, Label: 2015-07-27, Time Frame: 2015-07-27 (1D),
# Observation: 208, Label: 2015-07-28, Time Frame: 2015-07-28 (1D),
# Observation: 209, Label: 2015-07-29, Time Frame: 2015-07-29 (1D),
# Observation: 210, Label: 2015-07-30, Time Frame: 2015-07-30 (1D),
# Observation: 211, Label: 2015-07-31, Time Frame: 2015-07-31 (1D),
# Observation: 212, Label: 2015-08-01, Time Frame: 2015-08-01 (1D),
# Observation: 213, Label: 2015-08-02, Time Frame: 2015-08-02 (1D),
# Observation: 214, Label: 2015-08-03, Time Frame: 2015-08-03 (1D),
# Observation: 215, Label: 2015-08-04, Time Frame: 2015-08-04 (1D),
# Observation: 216, Label: 2015-08-05, Time Frame: 2015-08-05 (1D),
# Observation: 217, Label: 2015-08-06, Time Frame: 2015-08-06 (1D),
# Observation: 218, Label: 2015-08-07, Time Frame: 2015-08-07 (1D),
# Observation: 219, Label: 2015-08-08, Time Frame: 2015-08-08 (1D),
# Observation: 220, Label: 2015-08-09, Time Frame: 2015-08-09 (1D),
# Observation: 221, Label: 2015-08-10, Time Frame: 2015-08-10 (1D),
# Observation: 222, Label: 2015-08-11, Time Frame: 2015-08-11 (1D),
# Observation: 223, Label: 2015-08-12, Time Frame: 2015-08-12 (1D),
# Observation: 224, Label: 2015-08-13, Time Frame: 2015-08-13 (1D),
# Observation: 225, Label: 2015-08-14, Time Frame: 2015-08-14 (1D),
# Observation: 226, Label: 2015-08-15, Time Frame: 2015-08-15 (1D),
# Observation: 227, Label: 2015-08-16, Time Frame: 2015-08-16 (1D),
# Observation: 228, Label: 2015-08-17, Time Frame: 2015-08-17 (1D),
# Observation: 229, Label: 2015-08-18, Time Frame: 2015-08-18 (1D),
# Observation: 230, Label: 2015-08-19, Time Frame: 2015-08-19 (1D),
# Observation: 231, Label: 2015-08-20, Time Frame: 2015-08-20 (1D),
# Observation: 232, Label: 2015-08-21, Time Frame: 2015-08-21 (1D),
# Observation: 233, Label: 2015-08-22, Time Frame: 2015-08-22 (1D),
# Observation: 234, Label: 2015-08-23, Time Frame: 2015-08-23 (1D),
# Observation: 235, Label: 2015-08-24, Time Frame: 2015-08-24 (1D),
# Observation: 236, Label: 2015-08-25, Time Frame: 2015-08-25 (1D),
# Observation: 237, Label: 2015-08-26, Time Frame: 2015-08-26 (1D),
# Observation: 238, Label: 2015-08-27, Time Frame: 2015-08-27 (1D),
# Observation: 239, Label: 2015-08-28, Time Frame: 2015-08-28 (1D),
# Observation: 240, Label: 2015-08-29, Time Frame: 2015-08-29 (1D),
# Observation: 241, Label: 2015-08-30, Time Frame: 2015-08-30 (1D),
# Observation: 242, Label: 2015-08-31, Time Frame: 2015-08-31 (1D),
# Observation: 243, Label: 2015-09-01, Time Frame: 2015-09-01 (1D),
# Observation: 244, Label: 2015-09-02, Time Frame: 2015-09-02 (1D),
# Observation: 245, Label: 2015-09-03, Time Frame: 2015-09-03 (1D),
# Observation: 246, Label: 2015-09-04, Time Frame: 2015-09-04 (1D),
# Observation: 247, Label: 2015-09-05, Time Frame: 2015-09-05 (1D),
# Observation: 248, Label: 2015-09-06, Time Frame: 2015-09-06 (1D),
# Observation: 249, Label: 2015-09-07, Time Frame: 2015-09-07 (1D),
# Observation: 250, Label: 2015-09-08, Time Frame: 2015-09-08 (1D),
# Observation: 251, Label: 2015-09-09, Time Frame: 2015-09-09 (1D),
# Observation: 252, Label: 2015-09-10, Time Frame: 2015-09-10 (1D),
# Observation: 253, Label: 2015-09-11, Time Frame: 2015-09-11 (1D),
# Observation: 254, Label: 2015-09-12, Time Frame: 2015-09-12 (1D),
# Observation: 255, Label: 2015-09-13, Time Frame: 2015-09-13 (1D),
# Observation: 256, Label: 2015-09-14, Time Frame: 2015-09-14 (1D),
# Observation: 257, Label: 2015-09-15, Time Frame: 2015-09-15 (1D),
# Observation: 258, Label: 2015-09-16, Time Frame: 2015-09-16 (1D),
# Observation: 259, Label: 2015-09-17, Time Frame: 2015-09-17 (1D),
# Observation: 260, Label: 2015-09-18, Time Frame: 2015-09-18 (1D),
# Observation: 261, Label: 2015-09-19, Time Frame: 2015-09-19 (1D),
# Observation: 262, Label: 2015-09-20, Time Frame: 2015-09-20 (1D),
# Observation: 263, Label: 2015-09-21, Time Frame: 2015-09-21 (1D),
# Observation: 264, Label: 2015-09-22, Time Frame: 2015-09-22 (1D),
# Observation: 265, Label: 2015-09-23, Time Frame: 2015-09-23 (1D),
# Observation: 266, Label: 2015-09-24, Time Frame: 2015-09-24 (1D),
# Observation: 267, Label: 2015-09-25, Time Frame: 2015-09-25 (1D),
# Observation: 268, Label: 2015-09-26, Time Frame: 2015-09-26 (1D),
# Observation: 269, Label: 2015-09-27, Time Frame: 2015-09-27 (1D),
# Observation: 270, Label: 2015-09-28, Time Frame: 2015-09-28 (1D),
# Observation: 271, Label: 2015-09-29, Time Frame: 2015-09-29 (1D),
# Observation: 272, Label: 2015-09-30, Time Frame: 2015-09-30 (1D),
# Observation: 273, Label: 2015-10-01, Time Frame: 2015-10-01 (1D),
# Observation: 274, Label: 2015-10-02, Time Frame: 2015-10-02 (1D),
# Observation: 275, Label: 2015-10-03, Time Frame: 2015-10-03 (1D),
# Observation: 276, Label: 2015-10-04, Time Frame: 2015-10-04 (1D),
# Observation: 277, Label: 2015-10-05, Time Frame: 2015-10-05 (1D),
# Observation: 278, Label: 2015-10-06, Time Frame: 2015-10-06 (1D),
# Observation: 279, Label: 2015-10-07, Time Frame: 2015-10-07 (1D),
# Observation: 280, Label: 2015-10-08, Time Frame: 2015-10-08 (1D),
# Observation: 281, Label: 2015-10-09, Time Frame: 2015-10-09 (1D),
# Observation: 282, Label: 2015-10-10, Time Frame: 2015-10-10 (1D),
# Observation: 283, Label: 2015-10-11, Time Frame: 2015-10-11 (1D),
# Observation: 284, Label: 2015-10-12, Time Frame: 2015-10-12 (1D),
# Observation: 285, Label: 2015-10-13, Time Frame: 2015-10-13 (1D),
# Observation: 286, Label: 2015-10-14, Time Frame: 2015-10-14 (1D),
# Observation: 287, Label: 2015-10-15, Time Frame: 2015-10-15 (1D),
# Observation: 288, Label: 2015-10-16, Time Frame: 2015-10-16 (1D),
# Observation: 289, Label: 2015-10-17, Time Frame: 2015-10-17 (1D),
# Observation: 290, Label: 2015-10-18, Time Frame: 2015-10-18 (1D),
# Observation: 291, Label: 2015-10-19, Time Frame: 2015-10-19 (1D),
# Observation: 292, Label: 2015-10-20, Time Frame: 2015-10-20 (1D),
# Observation: 293, Label: 2015-10-21, Time Frame: 2015-10-21 (1D),
# Observation: 294, Label: 2015-10-22, Time Frame: 2015-10-22 (1D),
# Observation: 295, Label: 2015-10-23, Time Frame: 2015-10-23 (1D),
# Observation: 296, Label: 2015-10-24, Time Frame: 2015-10-24 (1D),
# Observation: 297, Label: 2015-10-25, Time Frame: 2015-10-25 (1D),
# Observation: 298, Label: 2015-10-26, Time Frame: 2015-10-26 (1D),
# Observation: 299, Label: 2015-10-27, Time Frame: 2015-10-27 (1D),
# Observation: 300, Label: 2015-10-28, Time Frame: 2015-10-28 (1D),
# Observation: 301, Label: 2015-10-29, Time Frame: 2015-10-29 (1D),
# Observation: 302, Label: 2015-10-30, Time Frame: 2015-10-30 (1D),
# Observation: 303, Label: 2015-10-31, Time Frame: 2015-10-31 (1D),
# Observation: 304, Label: 2015-11-01, Time Frame: 2015-11-01 (1D),
# Observation: 305, Label: 2015-11-02, Time Frame: 2015-11-02 (1D),
# Observation: 306, Label: 2015-11-03, Time Frame: 2015-11-03 (1D),
# Observation: 307, Label: 2015-11-04, Time Frame: 2015-11-04 (1D),
# Observation: 308, Label: 2015-11-05, Time Frame: 2015-11-05 (1D),
# Observation: 309, Label: 2015-11-06, Time Frame: 2015-11-06 (1D),
# Observation: 310, Label: 2015-11-07, Time Frame: 2015-11-07 (1D),
# Observation: 311, Label: 2015-11-08, Time Frame: 2015-11-08 (1D),
# Observation: 312, Label: 2015-11-09, Time Frame: 2015-11-09 (1D),
# Observation: 313, Label: 2015-11-10, Time Frame: 2015-11-10 (1D),
# Observation: 314, Label: 2015-11-11, Time Frame: 2015-11-11 (1D),
# Observation: 315, Label: 2015-11-12, Time Frame: 2015-11-12 (1D),
# Observation: 316, Label: 2015-11-13, Time Frame: 2015-11-13 (1D),
# Observation: 317, Label: 2015-11-14, Time Frame: 2015-11-14 (1D),
# Observation: 318, Label: 2015-11-15, Time Frame: 2015-11-15 (1D),
# Observation: 319, Label: 2015-11-16, Time Frame: 2015-11-16 (1D),
# Observation: 320, Label: 2015-11-17, Time Frame: 2015-11-17 (1D),
# Observation: 321, Label: 2015-11-18, Time Frame: 2015-11-18 (1D),
# Observation: 322, Label: 2015-11-19, Time Frame: 2015-11-19 (1D),
# Observation: 323, Label: 2015-11-20, Time Frame: 2015-11-20 (1D),
# Observation: 324, Label: 2015-11-21, Time Frame: 2015-11-21 (1D),
# Observation: 325, Label: 2015-11-22, Time Frame: 2015-11-22 (1D),
# Observation: 326, Label: 2015-11-23, Time Frame: 2015-11-23 (1D),
# Observation: 327, Label: 2015-11-24, Time Frame: 2015-11-24 (1D),
# Observation: 328, Label: 2015-11-25, Time Frame: 2015-11-25 (1D),
# Observation: 329, Label: 2015-11-26, Time Frame: 2015-11-26 (1D),
# Observation: 330, Label: 2015-11-27, Time Frame: 2015-11-27 (1D),
# Observation: 331, Label: 2015-11-28, Time Frame: 2015-11-28 (1D),
# Observation: 332, Label: 2015-11-29, Time Frame: 2015-11-29 (1D),
# Observation: 333, Label: 2015-11-30, Time Frame: 2015-11-30 (1D),
# Observation: 334, Label: 2015-12-01, Time Frame: 2015-12-01 (1D),
# Observation: 335, Label: 2015-12-02, Time Frame: 2015-12-02 (1D),
# Observation: 336, Label: 2015-12-03, Time Frame: 2015-12-03 (1D),
# Observation: 337, Label: 2015-12-04, Time Frame: 2015-12-04 (1D),
# Observation: 338, Label: 2015-12-05, Time Frame: 2015-12-05 (1D),
# Observation: 339, Label: 2015-12-06, Time Frame: 2015-12-06 (1D),
# Observation: 340, Label: 2015-12-07, Time Frame: 2015-12-07 (1D),
# Observation: 341, Label: 2015-12-08, Time Frame: 2015-12-08 (1D),
# Observation: 342, Label: 2015-12-09, Time Frame: 2015-12-09 (1D),
# Observation: 343, Label: 2015-12-10, Time Frame: 2015-12-10 (1D),
# Observation: 344, Label: 2015-12-11, Time Frame: 2015-12-11 (1D),
# Observation: 345, Label: 2015-12-12, Time Frame: 2015-12-12 (1D),
# Observation: 346, Label: 2015-12-13, Time Frame: 2015-12-13 (1D),
# Observation: 347, Label: 2015-12-14, Time Frame: 2015-12-14 (1D),
# Observation: 348, Label: 2015-12-15, Time Frame: 2015-12-15 (1D),
# Observation: 349, Label: 2015-12-16, Time Frame: 2015-12-16 (1D),
# Observation: 350, Label: 2015-12-17, Time Frame: 2015-12-17 (1D),
# Observation: 351, Label: 2015-12-18, Time Frame: 2015-12-18 (1D),
# Observation: 352, Label: 2015-12-19, Time Frame: 2015-12-19 (1D),
# Observation: 353, Label: 2015-12-20, Time Frame: 2015-12-20 (1D),
# Observation: 354, Label: 2015-12-21, Time Frame: 2015-12-21 (1D),
# Observation: 355, Label: 2015-12-22, Time Frame: 2015-12-22 (1D),
# Observation: 356, Label: 2015-12-23, Time Frame: 2015-12-23 (1D),
# Observation: 357, Label: 2015-12-24, Time Frame: 2015-12-24 (1D),
# Observation: 358, Label: 2015-12-25, Time Frame: 2015-12-25 (1D),
# Observation: 359, Label: 2015-12-26, Time Frame: 2015-12-26 (1D),
# Observation: 360, Label: 2015-12-27, Time Frame: 2015-12-27 (1D),
# Observation: 361, Label: 2015-12-28, Time Frame: 2015-12-28 (1D),
# Observation: 362, Label: 2015-12-29, Time Frame: 2015-12-29 (1D),
# Observation: 363, Label: 2015-12-30, Time Frame: 2015-12-30 (1D),
# Observation: 364, Label: 2015-12-31, Time Frame: 2015-12-31 (1D),

# %%
context = Context.of(
    scope=pf_rume.scope,
    # We fetch data starting from the first fitting date to match the first nowcast.
    time_frame=pf_rume.time_frame,
    rng=my_rng,
)
real_data_result = (
    my_observations.source.with_context_internal(context).inspect().result
)
real_data = real_data_result["value"]

real_data_dates = real_data_result["date"][:, 0]

# %%
import matplotlib.pyplot as plt

t_range = np.arange(pf_rume.time_frame.duration_days)

fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('Data fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(particle_filter_output.posterior_values[:,:,node,:],97.5,axis = 1)[:,0]
        lower = np.percentile(particle_filter_output.posterior_values[:,:,node,:],2.5,axis = 1)[:,0]
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].scatter(t_range,real_data[:,node],marker = 'x',color = 'red',s= 5)
ax[-1].set_xlabel('Days')
fig.tight_layout()

# %%
fig,ax = plt.subplots(4,figsize = (12,8),sharex=True)

plt.suptitle('$\\beta_t$ fit by Node')
for node in range(pf_rume.scope.nodes):
        upper = np.percentile(np.exp(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:,:,node]),97.5,axis = 0)
        lower = np.percentile(np.exp(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:,:,node]),2.5,axis = 0)
        beta_mean = np.mean(np.exp(particle_filter_output.estimated_params[NamePattern.of("log_beta")][:,:,node]),axis = 0)
        ax[node].set_title(f'{pf_rume.scope.labels[node]}')
        ax[node].fill_between(t_range,lower,upper)
        ax[node].plot(beta_mean,'--',label = 'mean',color = 'black')
        ax[node].scatter(t_range,beta[node,:].T,marker = 'x',color = 'red',s= 5,label = 'True Value')
        ax[node].legend()
ax[-1].set_xlabel('Days')
fig.tight_layout()
